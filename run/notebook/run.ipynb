# %%
# !cd ../../ && go run run/service/version/*.go -config service_version.json -ComponentId 1
# Out:
# 2023-04-06T21:24:55.780+0800	INFO	znet/servertcp.go:33	Listening on TCP: 124.221.147.27:9000 ...
# 2023-04-06T21:24:55.780+0800	ERROR	znet/servertcp.go:14	server@124.221.147.27:9000 failed with error: listen tcp 124.221.147.27:9000: bind: cannot assign requested address, will restart after 3s
# github.com/ouczbs/zmin/engine/net/znet.ServeTCPForever
# 	/data/jupyter/sync/zmin/engine/net/znet/servertcp.go:14
# github.com/ouczbs/zmin/component/version.(*UVersionService).Run
# 	/data/jupyter/sync/zmin/component/version/versionservice.go:21
# main.main
# 	/data/jupyter/sync/zmin/run/version/runversion.go:7
# runtime.main
# 	/usr/lib/go/src/runtime/proc.go:250
# 2023-04-06T21:24:58.781+0800	INFO	znet/servertcp.go:33	Listening on TCP: 124.221.147.27:9000 ...
# 2023-04-06T21:24:58.781+0800	ERROR	znet/servertcp.go:14	server@124.221.147.27:9000 failed with error: listen tcp 124.221.147.27:9000: bind: cannot assign requested address, will restart after 3s
# ...
